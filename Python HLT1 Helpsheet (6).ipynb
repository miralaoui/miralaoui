# %% [markdown]
# Task 1
# Write a program that does the following:
# a) Stores a random number (1-10) in a variable – see hint below.
# b) Asks a user for their name and stores this in a variable.
# c) Asks a user to guess the number between 1 and 10.
# d) Tells the user whether they have guessed correctly.
#
# Solution
# 1. import random library
# 2. Ask python to pick a random number between 1-10
# 3. Ask user what is their name
# 4. Ask user to guess a number
# 5. Create an IF statement to determine if the number the user guessed is the same as the random number generated by python

# %%
import random
rand_num = <select random number from random library>
user_name    = <ask user to input name>
guess_number = <ask use to input a number>

if <insert variable name> == <insert variable name>:
    print("You got it correct!, well done!")
else:
    print("You got it wrong, it was not:",<insert variable name> , "it was:", <insert variable name>)
    rand_num =

# %%
import random
rand_num = <select random number from random library>
user_name    = <ask user to input name>
guess_number = <ask use to input a number>

if <insert variable name> == <insert variable name>:
    print("You got it correct!, well done!")
else:
    print("You got it wrong, it was not:",<insert variable name> , "it was:", <insert variable name>)

# %%
import random
rand_num = random.randint(1,10)
user_name = input("What is your name?")
guess_number = int(input("Select a number between 1 and 10"))

if rand_num == guess_number:
    print("You got it correct! well done!")

else:
    print("You got it wrong, it was not:", guess_number , "it was:" , rand_num ,)
# Out:
# You got it wrong, it was not: 5 it was: 7

# %% [markdown]
# Task 2
# Write a program that asks a user for their favourite number between 1 and 100 and then tells them a joke based on the number. You should use a minimum of 3 jokes.
#
# Solution
# 1. Ask the user to pick a number
# 2. Create an IF statement which uses logical operators which prints out a joke based on the number the user picked

# %% [markdown]
# Task 3
# Write a program that allows user to enter their favourite starter, main course, dessert and drink.Concatenate these and output a message which says – “Your favourite meal is  ………with a glass of….”
#
# Solution
# 1. Ask the user what their favourite starter is
# 2. Ask the user what their favourite main is
# 3. Ask the user what their favourite dessert is
# 4. Ask the user what their favourite drink is
# 5. Concatenate together the users input into a a string and print out

# %% [markdown]
# Task 4
# A motorbike costs £2000 and loses 10% of its value every year. Using a loop, print the value of the bike every following year until it falls below £1000.
#
# Solution
# 1. Store the value of the bike against a variable
# 2. Create a while loop which subtracts 10% of the bikes value untill the value reaches £1000

# %% [markdown]
# Task 5
# Write a program which will ask for two numbers from a user. Then offer a menu to the user giving them a choice of operator:e.g. – Enter “a” if you want to add“b” if you want to subtract.
# Include +, -, /, *, ** square (to the power of). Once the user has selected which operator they wish to use, perform the calculation.
#
# Solution
# 1. Ask the user to pick a number
# 2. Ask the user to pick a second number
# 3. Ask the user to pick an operator
# 4. Create an IF statement to carry out the math operation using the users choice of numbers and choice of operator

# %% [markdown]
# Still stuck after using the above tips? See the below examples.
#
# In the folling examples for the HLT, in the <> insert the correct code to solve the solutions.

# %% [markdown]
# Task 1
# Write a program that does the following:
# a) Stores a random number (1-10) in a variable – see hint below.
# b) Asks a user for their name and stores this in a variable.
# c) Asks a user to guess the number between 1 and 10.
# d) Tells the user whether they have guessed correctly.

# %%
import random
rand_num = random.randint(1,10)
user_name = input("What is your name?")
guess_number = int(input("Select a number between 1 and 10"))

if  rand_num == guess_number:
    print("You got it correct!, well done!")
else:
    print("You got it wrong, it was not:", guess_number , "it was:", rand_num)
# Out:
# You got it correct!, well done!

# %% [markdown]
# Task 2
# Write a program that asks a user for their favourite number between 1 and 100 and then tells them a joke based on the number. You should use a minimum of 3 jokes

# %%
<ask user to input a number and store against a variable called number>

if number <use a logical operator to specify a range>:
    print("My wife told me to stop impersonating a flamingo. I had to put my foot down.")
elif number <use a logical operator to specify a range>:
    print("I was wondering why the frisbee kept getting bigger and bigger, but then it hit me.") 
elif number <use a logical operator to specify a range>:
    print("Don’t you hate it when someone answers their own questions? I do.")

# %%
number = int(input("Select a number between 0 and 100"))

if number < 30:
    print("Why is Santa so good at karate? He has a black belt.")
elif number < 60:
    print("Why does Santa go through the chimney? Because it soots him.")
elif number >= 60:
    print("Who is Santa's least favourite reindeer? Rude-olph.")
# Out:
# Why does Santa go through the chimney? Because it soots him.

# %% [markdown]
# Task 3
# Write a program that allows user to enter their favourite starter, main course, dessert and drink.Concatenate these and output a message which says – “Your favourite meal is  ………with a glass of….”

# %%
<ask the user what is their favourite starter and save against a variable>
<ask the user what is their favourite main and save against a variable>
<ask the user what is their favourite dessert and save against a variable>
<ask the user what is their favourite drink and save against a variable>

print("Your favourite meal is", <insert starter variable> , "as a starter, a", <insert main variable> , "as a main and", <insert dessert variable> , "as your dessert. With a drink of", <insert drink variable> , ".")

# %%
starter = input("What is your favourite starter?")
main = input("What is your favourite main course?")
dessert = input("What is your faovourite dessert?" )
drink = input("What is favourite drink?")

print(" Your favourite meal is" , starter , "as a starter, a" , main , " as a main and" , dessert , "as your dessert. With a drink of", drink ,".")
# Out:
#  Your favourite meal is hummus as a starter, a falafel  as a main and blueberry you as your dessert. With a drink of blueberries and yougurt .

# %% [markdown]
# Task 4
# A motorbike costs £2000 and loses 10% of its value every year. Using a loop, print the value of the bike every following year until it falls below £1000.

# %%
bike_value = 2000

while bike_value <insert a logical operator to specify a condition> :
    print("The bike is worth:", bike_value)
    bike_value <insert calculation to subtract 10%>

# %%
bike_value = 2000
while bike_value > 1000:
    print("The bike is worth:", bike_value)
    bike_value = bike_value * 0.90
# Out:
# The bike is worth: 2000
# The bike is worth: 1800.0
# The bike is worth: 1620.0
# The bike is worth: 1458.0
# The bike is worth: 1312.2
# The bike is worth: 1180.98
# The bike is worth: 1062.882

# %% [markdown]
# Task 5
# Write a program which will ask for two numbers from a user. Then offer a menu to the user giving them a choice of operator:e.g. – Enter “a” if you want to add“b” if you want to subtract.
# Include +, -, /, *, ** square (to the power of). Once the user has selected which operator they wish to use, perform the calculation.

# %%
<ask the user to pick a number>
<ask the user to pick a second number number>
<ask the user to pick a operator> 

if sign == <operator choice>:
    print( <number 1> + <number 2>)
elif sign == <operator choice>:
    print(<number 1> - <number 2>)
elif sign == <operator choice>:
    print(<number 1> / <number 2>)
elif sign == <operator choice>:
    print(<number 1> * <number 2>)
elif sign == <operator choice>:
    print(<number 1> ** <number 2>)
elif sign == <operator choice>:
    print(<number 1> % <number 2>)
elif sign == <operator choice>:
    print(<number 1> // <number 2>)
else:
    print("An appropriate operator was not selected!")

# %%
num_1 = int(input("Please enter a number:"))
num_2 = int(input( "Please enter a second number:"))
sign = input("Please enter a operator choice (+,-,/,*,**,%,//):")

if sign == "+":
    print(num_1+num_2)
elif sign == "-":
    print(num_1 -num_2)
elif sign == "/":
    print(num_1/ num_2)
elif sign == "*":
    print(num_1* num_2)
elif sign == "**":
    print(num_1 ** num_2)
elif sign == "%":
    print(num_1 // num_2)
else:
    print("An appropriate operator was not selected!")
# Out:
# 16
